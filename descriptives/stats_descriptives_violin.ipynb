# %% [markdown]
# # COURSE: Master statistics and machine learning: Intuition, Math, code
# ##### COURSE URL: udemy.com/course/statsml_x/?couponCode=202006
# ## SECTION: Descriptive statistics
# ### VIDEO: Violin plots
# #### TEACHER: Mike X Cohen, sincxpress.com

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
## create the data

n = 1000
thresh = 5 # threshold for cropping data

data = np.exp( np.random.randn(n) )

#all of the data points that exceed that threshold value gets redefined
#to be the threshold value + some randomly distributed that are scaled down by a factor of 10
data[data>thresh] = thresh + np.random.randn(sum(data>thresh))*.1

# show histogram
plt.hist(data,30)
plt.title('Histogram')
plt.show()

# show violin plot
plt.violinplot(data) #instamake violin plot
plt.title('Violin')
plt.show()

# %%
# another option: swarm plot

import seaborn as sns
sns.swarmplot(data,orient='v')
#like a violin plot but you get to see all the single data points
# Out:
# <AxesSubplot: >
# /Users/antonis/miniforge3/envs/dfl_test/lib/python3.8/site-packages/seaborn/categorical.py:3543: UserWarning: 5.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
